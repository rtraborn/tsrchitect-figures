# %% [markdown]
# ### Plotting the distribution of datasets relative to annotated TSSs

# %%
library(ggplot2)

# %%
library(reshape2)

# %%
setwd("/scratch/rtraborn/tsrchitect-figures/figures/")

# %%
coverage.out <- read.table(file="/scratch/rtraborn/tsrchitect-figures/output_files/At_coverage_hist_all_v_tss_annot.txt", skip=1, header=FALSE)

# %%
head(coverage.out)
# Out:
#   V1   V2       V3         V4         V5       V6         V7         V8
# 1 -300 4.714214 0.02078748 0.02091171 6.292356 0.01648867 0.03857415  9.502203
# 2 -290 4.655154 0.01946238 0.02240244 6.181424 0.01550632 0.02780755  9.575558
# 3 -280 4.573015 0.02024916 0.02066325 6.682619 0.03750277 0.02499933  9.366321
# 4 -270 4.503433 0.01913111 0.02107734 6.782563 0.01665013 0.02608957 10.065699
# 5 -260 4.416881 0.01950379 0.02360331 7.455474 0.01701756 0.03869713 10.716792
# 6 -250 4.295029 0.01875842 0.02190553 7.571443 0.01424782 0.05191885 10.471659
#   V9          V10        V11      V12         V13
# 1 0.013161356 0.07913054 11.06983 0.005111840 0.11210837
# 2 0.009261984 0.06916115 10.88523 0.004620298 0.08412911
# 3 0.009255738 0.05246740 11.26068 0.004467645 0.08543989
# 4 0.006975769 0.05706950 14.22073 0.004598926 0.10050165
# 5 0.006666567 0.07672877 16.74541 0.003899775 0.11403485
# 6 0.007149109 0.11558506 18.15683 0.004113490 0.10851390

# %%
colnames(coverage.out) <- c("Distance","ESTcoverage","EST_plusTags","EST_minusTags","CAGEcoverage","CAGE_plusTags","CAGE_minusTags","PEATcoverage","PEAT_plusTags","PEAT_minusTags","OligoCoverage","Oligo_plusTags","Oligo_minusTags")

# %%
head(coverage.out)
# Out:
#   Distance ESTcoverage EST_plusTags EST_minusTags CAGEcoverage CAGE_plusTags
# 1 -300     4.714214    0.02078748   0.02091171    6.292356     0.01648867
# 2 -290     4.655154    0.01946238   0.02240244    6.181424     0.01550632
# 3 -280     4.573015    0.02024916   0.02066325    6.682619     0.03750277
# 4 -270     4.503433    0.01913111   0.02107734    6.782563     0.01665013
# 5 -260     4.416881    0.01950379   0.02360331    7.455474     0.01701756
# 6 -250     4.295029    0.01875842   0.02190553    7.571443     0.01424782
#   CAGE_minusTags PEATcoverage PEAT_plusTags PEAT_minusTags OligoCoverage
# 1 0.03857415      9.502203    0.013161356   0.07913054     11.06983
# 2 0.02780755      9.575558    0.009261984   0.06916115     10.88523
# 3 0.02499933      9.366321    0.009255738   0.05246740     11.26068
# 4 0.02608957     10.065699    0.006975769   0.05706950     14.22073
# 5 0.03869713     10.716792    0.006666567   0.07672877     16.74541
# 6 0.05191885     10.471659    0.007149109   0.11558506     18.15683
#   Oligo_plusTags Oligo_minusTags
# 1 0.005111840    0.11210837
# 2 0.004620298    0.08412911
# 3 0.004467645    0.08543989
# 4 0.004598926    0.10050165
# 5 0.003899775    0.11403485
# 6 0.004113490    0.10851390

# %%
coverage.table <- cbind(coverage.out[,1:2],coverage.out[,5], coverage.out[,8], coverage.out[,11])

# %%
colnames(coverage.table) <- c("Distance","ESTcoverage","CAGEcoverage","PEATcoverage", "Oligocoverage")

# %%
head(coverage.table)
# Out:
#   Distance ESTcoverage CAGEcoverage PEATcoverage Oligocoverage
# 1 -300     4.714214    6.292356      9.502203    11.06983
# 2 -290     4.655154    6.181424      9.575558    10.88523
# 3 -280     4.573015    6.682619      9.366321    11.26068
# 4 -270     4.503433    6.782563     10.065699    14.22073
# 5 -260     4.416881    7.455474     10.716792    16.74541
# 6 -250     4.295029    7.571443     10.471659    18.15683

# %%
coverage.rs <- melt(coverage.table,id.vars = "Distance")

# %%
colnames(coverage.rs) <- c("Distance","dataset", "density")

# %%
head(coverage.rs)
# Out:
#   Distance dataset     density
# 1 -300     ESTcoverage 4.714214
# 2 -290     ESTcoverage 4.655154
# 3 -280     ESTcoverage 4.573015
# 4 -270     ESTcoverage 4.503433
# 5 -260     ESTcoverage 4.416881
# 6 -250     ESTcoverage 4.295029

# %%
a <- ggplot(coverage.rs)

# %%
a + geom_line(aes(x=Distance, y=density, colour=dataset))
# Out:
# plot without title

# %%
ggsave(file="At_peaks_v_annotated_genes.png")
# Out:
# Saving 6.67 x 6.67 in image
